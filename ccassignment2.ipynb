# %% [markdown]
# <a href="https://colab.research.google.com/github/encodingbits/UCS420/blob/main/ccassignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# total = sum(range(1,11))
# total

s = 0
for i in range(1,11):
  s=s+i
print(s)
# Out:
# 55

# %%
# WAP to print the table of n and n is given by user.
a=int(input("table of -> "))
for i in range(1,11):
  i=a*i
  print(i)
# Out:
# table of -> 6
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %%
# WAP to print the table of 7, 9.
for i in range(1,11):
  print(7*i)
for i in range(1,11):
  print(9*i)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %%
# WAP to add all the numbers from 1 to n and n is given by user.
a = int(input("Till which number you to add from 1: "))
summ = sum(range(1,a+1))
print(summ)
# Out:
# Till which number you to add from 1: 5
# 15

# %%
a=int(input("Enter a number to compare: "))
b=int(input("Enter a number to compare: "))
if a>b:
  print(str(a) + ">" + str(b))
elif a<b:
  print(str(a) + "<" + str(b))
else:
  print("Both numbers are equal.")
# Out:
# Enter a number to compare: 45
# Enter a number to compare: 45
# 45 and 45 are equal.

# %%
# checking odd or even
a=int(input("Enter a number to check odd or even "))
if a%2 == 0:
  print(str(a) + " is a even number")
else:
  print(str(a) + " is a odd number")
# Out:
# Enter a number to check odd or even48
# 48 is a even number

# %%
# checking prime no
print("Remember 2 is already a prime number.")
print("So enter number after 2.")
a = int(input("Enter no to check prime: "))
for i in range(2,a):
  if a%i == 0:
    print(str(a) + " is not a prime number because it is divisible by " + str(i))
    break
else:
    print(str(a) + " is a prime number")
# Out:
# Remember 2 is already a prime number.
# So enter number after 2.
# Enter no to check prime: 45
# 45 is not a prime number because it is divisible by 3

# %%
# comparing strings
a = input("enter first str: ")
b = input("enter second str: ")
if str(a) == str(b):
  print("Both strings are same")
else:
  print(a + " and " + b + " are not equal")
# Out:
# enter first str: computer
# enter second str: complete
# computer  and complete are not equal

# %%
# WAP to add all prime numbers from 1 to n and n is given by the user.
a = int(input("Enter till that number you want to add primes: "))
sum=0
for i in range(2,a+1):
  is_prime=True
  for j in range(2,i):
    if i%j == 0:
      is_prime = False
      break
  if is_prime == True:
    sum =sum + i

print(sum)
# Out:
# Enter till that number you want to add primes: 25
# 100

# %%
# WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.
a=int(input("Enter a number to add that are divisible by 7 and 9: "))
sum=0
for i in range(1,a+1):
  if (i % 7 == 0) and (i % 9 == 0):
    sum= sum + i
print(sum)
# Out:
# Enter a number to add that are divisible by 7 and 9: 70
# 63

# %%
# WAP to find max amoung three numbers and input from user. [Try max() function]
import numpy as np
a=int(input("Enter a no. : "))
b=int(input("Enter a no. : "))
c=int(input("Enter a no. : "))
maximum = max(a,b,c)
print(maximum)
# Out:
# Enter a no. : 3
# Enter a no. : 5
# Enter a no. : 4
# 5

# %%
# adding 2 no.s using functions
def add(a,b):
  c=a+b
  return c
print("adding no.s 203 nd 561 = ", add(203,561))
# Out:
# adding no.s 203 nd 561 =  764

# %%
# finding prime no
print("please enter no after 2 cuz even if 2 is even but it is prime also.")
print("0 -> no its not prime.")
print("1 -> yes it is prime.")
def isPrime(n):
  for i in range(2,n):
    if n%i == 0:
      return 0
  return 1
a = int(input("Enter no. to find prime or not: "))
isPrime(a)
# Out:
# please enter no after 2 cuz even if 2 is even but it is prime also.
# 0 -> no its not prime.
# 1 -> yes it is prime.
# Enter no. to find prime or not: 9
# 0

# %%
# adding 1 to n
def addtill(n):
  sum=0
  for i in range(1,n+1):
    sum = sum+i
  print("sum from 1 to ", n," = " , sum)
a = int(input("Enter no. for sum: "))
addtill(a)
# Out:
# Enter no. for sum: 010
# sum from 1 to  10  =  55

# %%
# WAP using function that add all odd numbers from 1 to n, n is given by the user.
def addtill(n):
  sum=0
  for i in range(1,n+1):
    if i%2 != 0:
      sum = sum+i
  print("sum from 1 to ", n," = " , sum)
a = int(input("Enter a no. for odd no.s sum: "))
addtill(a)
# Out:
# Enter a no. for odd no.s sum: 9
# sum from 1 to  9  =  25

# %%
# WAP using function that add all prime numbers from 1 to n, n given by the user.
def addprimetill(n):
  sum = 0

  for i in range(2,n+1):
    for j in range(2, i):
      if i%j == 0:
        break
    else:
        sum = sum + i

  print(sum)

a= int(input("Enter no to get sum of prime nos: "))
addprimetill(a)
# Out:
# Enter no to get sum of prime nos: 9
# 17

# %%
import math as ma
print("exp (-200) --> ", ma.exp(-200))
print("log(100,2) --> ", ma.log(100,2))
print("log(100,10) --> ", ma.log(100,10))
print("log10(100) -- > ", ma.log10(100))
print("cos(30) --> ", ma.cos(30))
print("sin(30) --> ", ma.sin(30))
print("tan(30) --> ", ma.tan(30))
print("sqrt(30) --> ", ma.sqrt(30))
print("ceil(89.9) --> ", ma.ceil(89.9))
print("floor(89.9) --> ", ma.floor(89.9))
# Out:
# exp (-200) -->  1.3838965267367376e-87
# log(100,2) -->  6.643856189774725
# log(100,10) -->  2.0
# log10(100) -- >  2.0
# cos(30) -->  0.15425144988758405
# sin(30) -->  -0.9880316240928618
# tan(30) -->  -6.405331196646276
# sqrt(30) -->  5.477225575051661
# ceil(89.9) -->  90
# floor(89.9) -->  89
